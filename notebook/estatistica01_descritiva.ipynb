# %% [markdown]
# # Estatística descritiva

# %%
# importando bibliotecas
import pandas as pd
import numpy as np

# %% [markdown]
# ### Variável

# %% [markdown]
# **Exemplo:** Suponha uma pesquisa realizada para se traçar o perfil dos frequentadores de um parque.
# Para reunir essas informações, 20 pessoas foram entrevistadas e cada uma respondeu a questões para identificar sexo, idade, número de visitas ao parque  por semana, estado cívil, meio de transporte utilizado para chegar ao parque, tempo de permanência (min) ao parque e renda familiar mensal (em salários mínimos).

# %%
#print(df_parque.to_latex(index=False,
#                  formatters={"name": str.upper},
#                  float_format="{:.1f}".format,
#))

# %%
# lendo os dados
df_parque = pd.read_csv("../data/descritiva/perfil_freq_parque.csv",sep=';')

# %%
# mostrando o dataframe
df_parque
# Out:
#     Unnamed: 0       Sexo  Idade  Frequência semanal Estado Civil  \
# 0            0  Masculino     26                   2    casada(o)
# 1            1  Masculino     23                   1  solteira(o)
# 2            2   Feminino     41                   5     viúva(o)
# 3            3  Masculino     49                   3  separada(o)
# 4            4   Feminino     19                   5  solteira(o)
# 5            5   Feminino     20                   4  solteira(o)
# 6            6  Masculino     27                   3  solteira(o)
# 7            7  Masculino     38                   3    casada(o)
# 8            8  Masculino     27                   2  separada(o)
# 9            9   Feminino     50                   7    casada(o)
# 10          10  Masculino     52                   2  solteira(o)
# 11          11   Feminino     48                   4    casada(o)
# 12          12  Masculino     28                   4    casada(o)
# 13          13  Masculino     36                   1    casada(o)
# 14          14   Feminino     31                   3  solteira(o)
# 15          15  Masculino     56                   3     viúva(o)
# 16          16   Feminino     41                   6  solteira(o)
# 17          17  Masculino     44                   1    casada(o)
# 18          18   Feminino     29                   2  separada(o)
# 19          19  Masculino     31                   3    casada(o)
#
#    Meio de transporte  Tempo de permanência (min)  \
# 0               carro                          30
# 1              ônibus                          35
# 2                a pé                         170
# 3                a pé                          45
# 4               carro                          60
# 5                a pé                          80
# 6               carro                          45
# 7                a pé                         135
# 8              ônibus                          80
# 9                a pé                          45
# 10               a pé                         100
# 11               a pé                          75
# 12               a pé                          60
# 13              carro                          90
# 14             ônibus                         120
# 15               a pé                          30
# 16              carro                         150
# 17             ônibus                          50
# 18               a pé                          40
# 19             ônibus                         165
#
#     Renda familiar mensal (sal. mínimo)
# 0                                  13.3
# 1                                  11.8
# 2                                   8.9
# 3                                  13.9
# 4                                  11.6
# 5                                  16.0
# 6                                  19.5
# 7                                   9.3
# 8                                  10.2
# 9                                  12.4
# 10                                 10.7
# 11                                 14.7
# 12                                 16.6
# 13                                 12.5
# 14                                  8.2
# 15                                 15.4
# 16                                 18.8
# 17                                 12.1
# 18                                  5.0
# 19                                  7.6

# %% [markdown]
# ### Tabela de frequência

# %% [markdown]
# **Estado cívil**

# %% [markdown]
# - Frequência absoluta

# %%
serie_ni = df_parque['Estado Civil'].value_counts()
serie_ni
# Out:
# Estado Civil
# casada(o)      8
# solteira(o)    7
# separada(o)    3
# viúva(o)       2
# Name: count, dtype: int64

# %%
n = serie_ni.sum()
n
# Out:
# 20

# %% [markdown]
# - Frequência relativa: $f_i = \dfrac{n_i}{n}$

# %%
#serie_fi = df_parque['Estado Civil'].value_counts()/n
#serie_fi

serie_fi = df_parque['Estado Civil'].value_counts(normalize = True)
serie_fi
# Out:
# Estado Civil
# casada(o)      0.40
# solteira(o)    0.35
# separada(o)    0.15
# viúva(o)       0.10
# Name: proportion, dtype: float64

# %% [markdown]
# - Percentual referente a frequência relativa

# %%
#serie_perc = df_parque['Estado Civil'].value_counts()/20*100
#serie_perc

serie_perc = df_parque['Estado Civil'].value_counts(normalize = True)*100
serie_perc
# Out:
# Estado Civil
# casada(o)      40.0
# solteira(o)    35.0
# separada(o)    15.0
# viúva(o)       10.0
# Name: proportion, dtype: float64

# %%
# Combina todas as informações em uma tabela
tab_freq = pd.DataFrame({
    'ni': serie_ni,
    'fi': serie_fi,
    'perc' : serie_perc
})

tab_freq
# Out:
#               ni    fi  perc
# Estado Civil
# casada(o)      8  0.40  40.0
# solteira(o)    7  0.35  35.0
# separada(o)    3  0.15  15.0
# viúva(o)       2  0.10  10.0

# %%
tab_freq = tab_freq.reset_index()
tab_freq
# Out:
#   Estado Civil  ni    fi  perc
# 0    casada(o)   8  0.40  40.0
# 1  solteira(o)   7  0.35  35.0
# 2  separada(o)   3  0.15  15.0
# 3     viúva(o)   2  0.10  10.0

# %%
tab = pd.DataFrame()
tab = pd.concat([tab, tab_freq], ignore_index=True)

resume = pd.DataFrame({
    'Estado Civil':f'Total',
    'ni':tab['ni'].sum(),
    'fi':tab['fi'].sum(),
    'perc':tab['perc'].sum(),
    }, index = ["resume"])

tab = pd.concat([tab, resume], ignore_index=True)

tab
# Out:
#   Estado Civil  ni    fi   perc
# 0    casada(o)   8  0.40   40.0
# 1  solteira(o)   7  0.35   35.0
# 2  separada(o)   3  0.15   15.0
# 3     viúva(o)   2  0.10   10.0
# 4        Total  20  1.00  100.0

# %% [markdown]
# **Renda familiar**

# %% [markdown]
# - Tabela (dataframe)

# %%
serie_rm = df_parque['Renda familiar mensal (sal. mínimo)']
df_rm = pd.DataFrame({'Renda':serie_rm.values})
df_rm
# Out:
#     Renda
# 0    13.3
# 1    11.8
# 2     8.9
# 3    13.9
# 4    11.6
# 5    16.0
# 6    19.5
# 7     9.3
# 8    10.2
# 9    12.4
# 10   10.7
# 11   14.7
# 12   16.6
# 13   12.5
# 14    8.2
# 15   15.4
# 16   18.8
# 17   12.1
# 18    5.0
# 19    7.6

# %% [markdown]
# - Intervalo de classes

# %%
# define os intervalos de classe
bins = [5, 8, 11, 14, 17, 20]

# %%
# cria a coluna de intervalos de classe
df_rm['Intervalo de Classe'] = pd.cut(df_rm['Renda'], bins, include_lowest=True)
df_rm
# Out:
#     Renda Intervalo de Classe
# 0    13.3        (11.0, 14.0]
# 1    11.8        (11.0, 14.0]
# 2     8.9         (8.0, 11.0]
# 3    13.9        (11.0, 14.0]
# 4    11.6        (11.0, 14.0]
# 5    16.0        (14.0, 17.0]
# 6    19.5        (17.0, 20.0]
# 7     9.3         (8.0, 11.0]
# 8    10.2         (8.0, 11.0]
# 9    12.4        (11.0, 14.0]
# 10   10.7         (8.0, 11.0]
# 11   14.7        (14.0, 17.0]
# 12   16.6        (14.0, 17.0]
# 13   12.5        (11.0, 14.0]
# 14    8.2         (8.0, 11.0]
# 15   15.4        (14.0, 17.0]
# 16   18.8        (17.0, 20.0]
# 17   12.1        (11.0, 14.0]
# 18    5.0        (4.999, 8.0]
# 19    7.6        (4.999, 8.0]

# %% [markdown]
# - Frequência absoluta

# %%
# cria a tabela de distribuição de frequências absoluta
serie_ni = df_rm['Intervalo de Classe'].value_counts(sort=False)
serie_ni
# Out:
# Intervalo de Classe
# (4.999, 8.0]    2
# (8.0, 11.0]     5
# (11.0, 14.0]    7
# (14.0, 17.0]    4
# (17.0, 20.0]    2
# Name: count, dtype: int64

# %%
# organiza os intervalos de classe em ordem crescente
serie_ni = serie_ni.sort_index()
serie_ni
# Out:
# Intervalo de Classe
# (4.999, 8.0]    2
# (8.0, 11.0]     5
# (11.0, 14.0]    7
# (14.0, 17.0]    4
# (17.0, 20.0]    2
# Name: count, dtype: int64

# %% [markdown]
# - Frequência relativa

# %%
# calcula as frequências relativas
serie_fi = serie_ni / serie_ni.sum()
serie_fi
# Out:
# Intervalo de Classe
# (4.999, 8.0]    0.10
# (8.0, 11.0]     0.25
# (11.0, 14.0]    0.35
# (14.0, 17.0]    0.20
# (17.0, 20.0]    0.10
# Name: count, dtype: float64

# %%
# calcula o percentual referente as frequências relativas
serie_perc = serie_fi * 100
serie_perc
# Out:
# Intervalo de Classe
# (4.999, 8.0]    10.0
# (8.0, 11.0]     25.0
# (11.0, 14.0]    35.0
# (14.0, 17.0]    20.0
# (17.0, 20.0]    10.0
# Name: count, dtype: float64

# %% [markdown]
# - Frequência absoluta acumulada

# %%
# calcula as frequências absoluta acumuladas
serie_ni_ac = serie_ni.cumsum()
serie_ni_ac
# Out:
# Intervalo de Classe
# (4.999, 8.0]     2
# (8.0, 11.0]      7
# (11.0, 14.0]    14
# (14.0, 17.0]    18
# (17.0, 20.0]    20
# Name: count, dtype: int64

# %% [markdown]
# - Frequência relativa acumulada

# %%
# calcula as frequências relativa acumuladas
serie_fi_ac = serie_fi.cumsum()
serie_fi_ac
# Out:
# Intervalo de Classe
# (4.999, 8.0]    0.10
# (8.0, 11.0]     0.35
# (11.0, 14.0]    0.70
# (14.0, 17.0]    0.90
# (17.0, 20.0]    1.00
# Name: count, dtype: float64

# %% [markdown]
# - Tabela de freqência

# %%
# combina todas as informações em uma tabela
tab_freq = pd.DataFrame({
    'ni': serie_ni,
    'fi': serie_fi,
    'perc': serie_perc,
    'ni ac': serie_ni_ac,
    'fi ac': serie_fi_ac
})

tab_freq
# Out:
#                      ni    fi  perc  ni ac  fi ac
# Intervalo de Classe
# (4.999, 8.0]          2  0.10  10.0      2   0.10
# (8.0, 11.0]           5  0.25  25.0      7   0.35
# (11.0, 14.0]          7  0.35  35.0     14   0.70
# (14.0, 17.0]          4  0.20  20.0     18   0.90
# (17.0, 20.0]          2  0.10  10.0     20   1.00

# %%
tab_freq = tab_freq.reset_index()
tab_freq
# Out:
#   Intervalo de Classe  ni    fi  perc  ni ac  fi ac
# 0        (4.999, 8.0]   2  0.10  10.0      2   0.10
# 1         (8.0, 11.0]   5  0.25  25.0      7   0.35
# 2        (11.0, 14.0]   7  0.35  35.0     14   0.70
# 3        (14.0, 17.0]   4  0.20  20.0     18   0.90
# 4        (17.0, 20.0]   2  0.10  10.0     20   1.00

# %%
tab = pd.DataFrame()
tab = pd.concat([tab, tab_freq], ignore_index=True)

resume = pd.DataFrame({
    'Intervalo de Classe':f'Total',
    'ni':tab['ni'].sum(),
    'fi':tab['fi'].sum(),
    'perc':tab['perc'].sum(),
    'ni ac':'',
    'fi ac':''
    }, index = ["resume"])

tab = pd.concat([tab, resume], ignore_index=True)

tab
# Out:
#   Intervalo de Classe  ni    fi   perc ni ac fi ac
# 0        (4.999, 8.0]   2  0.10   10.0     2   0.1
# 1         (8.0, 11.0]   5  0.25   25.0     7  0.35
# 2        (11.0, 14.0]   7  0.35   35.0    14   0.7
# 3        (14.0, 17.0]   4  0.20   20.0    18   0.9
# 4        (17.0, 20.0]   2  0.10   10.0    20   1.0
# 5               Total  20  1.00  100.0

# %% [markdown]
# **Tempo de permanência**

# %%
serie_tp = df_parque['Tempo de permanência (min)']
#serie_tp = serie_tp.sort_values(ascending=True)
serie_tp = pd.DataFrame({'Tempo':serie_tp.values})
serie_tp
# Out:
#     Tempo
# 0      30
# 1      35
# 2     170
# 3      45
# 4      60
# 5      80
# 6      45
# 7     135
# 8      80
# 9      45
# 10    100
# 11     75
# 12     60
# 13     90
# 14    120
# 15     30
# 16    150
# 17     50
# 18     40
# 19    165

# %%
# define os intervalos de classe
bins = [30, 60, 90, 120, 150, 180]

# %%
# cria a coluna de intervalos de classe
serie_tp['Intervalo de Classe'] = pd.cut(serie_tp['Tempo'], bins,  include_lowest=True)
serie_tp
# Out:
#     Tempo Intervalo de Classe
# 0      30      (29.999, 60.0]
# 1      35      (29.999, 60.0]
# 2     170      (150.0, 180.0]
# 3      45      (29.999, 60.0]
# 4      60      (29.999, 60.0]
# 5      80        (60.0, 90.0]
# 6      45      (29.999, 60.0]
# 7     135      (120.0, 150.0]
# 8      80        (60.0, 90.0]
# 9      45      (29.999, 60.0]
# 10    100       (90.0, 120.0]
# 11     75        (60.0, 90.0]
# 12     60      (29.999, 60.0]
# 13     90        (60.0, 90.0]
# 14    120       (90.0, 120.0]
# 15     30      (29.999, 60.0]
# 16    150      (120.0, 150.0]
# 17     50      (29.999, 60.0]
# 18     40      (29.999, 60.0]
# 19    165      (150.0, 180.0]

# %%
# cria a tabela de distribuição de frequências absoluta
serie_ni = serie_tp['Intervalo de Classe'].value_counts(sort=False)
serie_ni
# Out:
# Intervalo de Classe
# (29.999, 60.0]    10
# (60.0, 90.0]       4
# (90.0, 120.0]      2
# (120.0, 150.0]     2
# (150.0, 180.0]     2
# Name: count, dtype: int64

# %%
# organiza os intervalos de classe em ordem crescente
serie_ni = serie_ni.sort_index()
serie_ni
# Out:
# Intervalo de Classe
# (29.999, 60.0]    10
# (60.0, 90.0]       4
# (90.0, 120.0]      2
# (120.0, 150.0]     2
# (150.0, 180.0]     2
# Name: count, dtype: int64

# %%
# calcula as frequências relativas
serie_fi = serie_ni / serie_ni.sum()
serie_fi
# Out:
# Intervalo de Classe
# (29.999, 60.0]    0.5
# (60.0, 90.0]      0.2
# (90.0, 120.0]     0.1
# (120.0, 150.0]    0.1
# (150.0, 180.0]    0.1
# Name: count, dtype: float64

# %%
# calcula as frequências absoluta acumuladas
serie_ni_ac = serie_ni.cumsum()
serie_ni_ac
# Out:
# Intervalo de Classe
# (29.999, 60.0]    10
# (60.0, 90.0]      14
# (90.0, 120.0]     16
# (120.0, 150.0]    18
# (150.0, 180.0]    20
# Name: count, dtype: int64

# %%
# combina todas as informações em uma tabela
tab_freq_tp = pd.DataFrame({
    'ni': serie_ni,
    'fi': serie_fi,
    'ni ac': serie_ni_ac
})

tab_freq_tp
# Out:
#                      ni   fi  ni ac
# Intervalo de Classe
# (29.999, 60.0]       10  0.5     10
# (60.0, 90.0]          4  0.2     14
# (90.0, 120.0]         2  0.1     16
# (120.0, 150.0]        2  0.1     18
# (150.0, 180.0]        2  0.1     20

# %% [markdown]
# **Exemplo :**
# Suponha que foram coletados dados relativos à idade (em ano) e ao peso (em quilograma) de um grupo de adolescentes.
# O resultado dessa pesquisa, feita com uma amostra de 30 adolescentes, é mostrado na tabela a seguir:

# %%
# lendo os dados e mostrando df
df_adol = pd.read_csv("../data/descritiva/idade_peso_adolecentes.csv",sep=';')
df_adol
# Out:
#     idade  peso
# 0      14  48.5
# 1      15  51.0
# 2      15  51.0
# 3      16  51.5
# 4      14  51.4
# 5      14  53.0
# 6      17  49.2
# 7      15  50.3
# 8      16  50.3
# 9      14  50.0
# 10     16  48.0
# 11     16  49.4
# 12     14  53.0
# 13     17  50.0
# 14     15  53.0
# 15     16  50.3
# 16     15  53.0
# 17     15  53.0
# 18     16  50.3
# 19     16  50.0
# 20     15  48.5
# 21     16  49.1
# 22     14  50.0
# 23     16  50.0
# 24     15  52.4
# 25     17  53.0
# 26     15  51.1
# 27     15  51.1
# 28     15  52.4
# 29     15  52.3

# %%
serie_ni = df_adol["idade"].value_counts()
serie_ni
# Out:
# idade
# 15    12
# 16     9
# 14     6
# 17     3
# Name: count, dtype: int64

# %% [markdown]
# A variável idade é quantitativa discreta, portanto, podemos indicar a quantidade de vezes em que cada valor atribuído a essa variável foi citado por meio da frequência absoluta ($n_i$).
# Em relação a variável idade, temos:
#
# - 14 anos: 6 vezes
# - 15 anos: 12 vezes
# - 16 anos: 9 vezes
# - 17 anos: 3 vezes

# %%
serie_fi = df_adol['idade'].value_counts(normalize = True)
serie_fi
# Out:
# idade
# 15    0.4
# 16    0.3
# 14    0.2
# 17    0.1
# Name: proportion, dtype: float64

# %% [markdown]
# Para comparar a participação de cada um desses valores em relação ao todo, usamos a frequência relativa ($f_i$), que é a razão entre a frequência absoluta e o total de elementos do conjunto ($n$), ou seja, $f_i = \frac{n_i}{n}$
# Em relação à variável idade, considerando 30 adolescentes, temos:
# - 14 anos: $\frac{6}{30} = 0.2$
# - 15 anos: $\frac{12}{30} = 0.4$
# - 16 anos: $\frac{9}{30} = 0.3$
# - 17 anos: $\frac{3}{10} = 0.1$

# %%
serie_perc = df_adol['idade'].value_counts(normalize = True)*100
serie_perc
# Out:
# idade
# 15    40.0
# 16    30.0
# 14    20.0
# 17    10.0
# Name: proportion, dtype: float64

# %% [markdown]
# A frequência absoluta acumulada ($ni\_ac$) e a frequência relativa acumulada ($fi\_ac$) correspondem, respectivamente, a soma das frequências absolutas e a soma das frequências relativas até determinado dado.

# %%
# Calcula as frequências absoluta acumuladas
serie_ni_ac = serie_ni.cumsum()
serie_ni_ac
# Out:
# idade
# 15    12
# 16    21
# 14    27
# 17    30
# Name: count, dtype: int64

# %%
# Calcula as frequências relativa acumuladas
serie_fi_ac = serie_fi.cumsum()
serie_fi_ac
# Out:
# idade
# 15    0.4
# 16    0.7
# 14    0.9
# 17    1.0
# Name: proportion, dtype: float64

# %%
# Combina todas as informações em uma tabela
tab_freq = pd.DataFrame({
    'ni': serie_ni,
    'fi': serie_fi,
    'perc' : serie_perc,
    'ni_ac' : serie_ni_ac,
    'fi_ac' : serie_fi_ac
})

tab_freq
# Out:
#        ni   fi  perc  ni_ac  fi_ac
# idade
# 15     12  0.4  40.0     12    0.4
# 16      9  0.3  30.0     21    0.7
# 14      6  0.2  20.0     27    0.9
# 17      3  0.1  10.0     30    1.0

# %%
tab_freq = tab_freq.reset_index()
tab_freq
# Out:
#    idade  ni   fi  perc  ni_ac  fi_ac
# 0     15  12  0.4  40.0     12    0.4
# 1     16   9  0.3  30.0     21    0.7
# 2     14   6  0.2  20.0     27    0.9
# 3     17   3  0.1  10.0     30    1.0

# %%
tab = pd.DataFrame()
tab = pd.concat([tab, tab_freq], ignore_index=True)

resume = pd.DataFrame({
    'idade':f'Total',
    'ni':tab['ni'].sum(),
    'fi':tab['fi'].sum(),
    'perc':tab['perc'].sum(),
    'ni_ac': '',
    'fi_ac': ''
    }, index = ["resume"])

tab_freq = pd.concat([tab, resume], ignore_index=True)

tab_freq
# Out:
#    idade  ni   fi   perc ni_ac fi_ac
# 0     15  12  0.4   40.0    12   0.4
# 1     16   9  0.3   30.0    21   0.7
# 2     14   6  0.2   20.0    27   0.9
# 3     17   3  0.1   10.0    30   1.0
# 4  Total  30  1.0  100.0

# %%
df_adol.columns
# Out:
# Index(['idade', 'peso'], dtype='object')

# %%
peso_max = df_adol['peso'].max()
peso_min = df_adol['peso'].min()

# %%
print(f"peso max = {peso_max}")
print(f"peso min = {peso_min}")
# Out:
# peso max = 53.0
# peso min = 48.0

# %%
dif = peso_max - peso_min
print(dif)
# Out:
# 5.0

# %%
bins = [48,49,50,51,52,53]

# %%
serie_adol = df_adol['peso']

# %%
serie_peso = df_adol['peso']
serie_peso = pd.DataFrame({'peso':serie_peso.values})
serie_peso
# Out:
#     peso
# 0   48.5
# 1   51.0
# 2   51.0
# 3   51.5
# 4   51.4
# 5   53.0
# 6   49.2
# 7   50.3
# 8   50.3
# 9   50.0
# 10  48.0
# 11  49.4
# 12  53.0
# 13  50.0
# 14  53.0
# 15  50.3
# 16  53.0
# 17  53.0
# 18  50.3
# 19  50.0
# 20  48.5
# 21  49.1
# 22  50.0
# 23  50.0
# 24  52.4
# 25  53.0
# 26  51.1
# 27  51.1
# 28  52.4
# 29  52.3

# %%
# Cria a coluna de intervalos de classe
serie_peso['Intervalo de Classe'] = pd.cut(serie_peso['peso'], bins, include_lowest=True)
serie_peso
# Out:
#     peso Intervalo de Classe
# 0   48.5      (47.999, 49.0]
# 1   51.0        (50.0, 51.0]
# 2   51.0        (50.0, 51.0]
# 3   51.5        (51.0, 52.0]
# 4   51.4        (51.0, 52.0]
# 5   53.0        (52.0, 53.0]
# 6   49.2        (49.0, 50.0]
# 7   50.3        (50.0, 51.0]
# 8   50.3        (50.0, 51.0]
# 9   50.0        (49.0, 50.0]
# 10  48.0      (47.999, 49.0]
# 11  49.4        (49.0, 50.0]
# 12  53.0        (52.0, 53.0]
# 13  50.0        (49.0, 50.0]
# 14  53.0        (52.0, 53.0]
# 15  50.3        (50.0, 51.0]
# 16  53.0        (52.0, 53.0]
# 17  53.0        (52.0, 53.0]
# 18  50.3        (50.0, 51.0]
# 19  50.0        (49.0, 50.0]
# 20  48.5      (47.999, 49.0]
# 21  49.1        (49.0, 50.0]
# 22  50.0        (49.0, 50.0]
# 23  50.0        (49.0, 50.0]
# 24  52.4        (52.0, 53.0]
# 25  53.0        (52.0, 53.0]
# 26  51.1        (51.0, 52.0]
# 27  51.1        (51.0, 52.0]
# 28  52.4        (52.0, 53.0]
# 29  52.3        (52.0, 53.0]

# %%
# Cria a tabela de distribuição de frequências absoluta
serie_ni = serie_peso['Intervalo de Classe'].value_counts(sort=False)
serie_ni
# Out:
# Intervalo de Classe
# (47.999, 49.0]    3
# (49.0, 50.0]      8
# (50.0, 51.0]      6
# (51.0, 52.0]      4
# (52.0, 53.0]      9
# Name: count, dtype: int64

# %%
# Organiza os intervalos de classe em ordem crescente
serie_ni = serie_ni.sort_index()
serie_ni
# Out:
# Intervalo de Classe
# (47.999, 49.0]    3
# (49.0, 50.0]      8
# (50.0, 51.0]      6
# (51.0, 52.0]      4
# (52.0, 53.0]      9
# Name: count, dtype: int64

# %%
# Calcula as frequências relativas
serie_fi = serie_ni / serie_ni.sum()
serie_fi
# Out:
# Intervalo de Classe
# (47.999, 49.0]    0.100000
# (49.0, 50.0]      0.266667
# (50.0, 51.0]      0.200000
# (51.0, 52.0]      0.133333
# (52.0, 53.0]      0.300000
# Name: count, dtype: float64

# %%
# Combina todas as informações em uma tabela
tab_freq = pd.DataFrame({
    'ni': serie_ni,
    'fi': serie_fi
})

tab_freq
# Out:
#                      ni        fi
# Intervalo de Classe
# (47.999, 49.0]        3  0.100000
# (49.0, 50.0]          8  0.266667
# (50.0, 51.0]          6  0.200000
# (51.0, 52.0]          4  0.133333
# (52.0, 53.0]          9  0.300000

# %%
tab_freq = tab_freq.reset_index()
tab_freq
# Out:
#   Intervalo de Classe  ni        fi
# 0      (47.999, 49.0]   3  0.100000
# 1        (49.0, 50.0]   8  0.266667
# 2        (50.0, 51.0]   6  0.200000
# 3        (51.0, 52.0]   4  0.133333
# 4        (52.0, 53.0]   9  0.300000

# %%
tab = pd.DataFrame()
tab = pd.concat([tab, tab_freq], ignore_index=True)

resume = pd.DataFrame({
    'Intervalo de Classe':f'Total',
    'ni':tab['ni'].sum(),
    'fi':tab['fi'].sum(),
    }, index = ["resume"])

tab_freq = pd.concat([tab, resume], ignore_index=True)

tab_freq
# Out:
#   Intervalo de Classe  ni        fi
# 0      (47.999, 49.0]   3  0.100000
# 1        (49.0, 50.0]   8  0.266667
# 2        (50.0, 51.0]   6  0.200000
# 3        (51.0, 52.0]   4  0.133333
# 4        (52.0, 53.0]   9  0.300000
# 5               Total  30  1.000000
